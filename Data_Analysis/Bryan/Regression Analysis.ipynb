# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
clean_data_df = pd.read_csv('clean_data.csv')
clean_data_df.head()
# Out:
#    Unnamed: 0                Team  Assists Per. Game Rank  \
# 0           0  A&M-Corpus Christi                      44
# 1           1   Abilene Christian                      52
# 2           2           Air Force                     206
# 3           3               Akron                     278
# 4           4         Alabama A&M                     347
#
#    Assist Turnover Ratio Rank  BlocksPerGame Rank  Field Goal % Rank  \
# 0                         141                 343                156
# 1                          76                 338                194
# 2                         265                 190                203
# 3                         177                 162                 70
# 4                         346                 164                349
#
#    Field Goal % Defense Rank  Fouls Per Game Rank  Free Throw % Rank  \
# 0                         90                  349                100
# ...

# %%
clean_data_df.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Assists Per. Game Rank',
#        'Assist Turnover Ratio Rank', 'BlocksPerGame Rank', 'Field Goal % Rank',
#        'Field Goal % Defense Rank', 'Fouls Per Game Rank', 'Free Throw % Rank',
#        'Rebound Margin Rank', 'Scoring Defense Rank', 'Scoring Margin Rank',
#        'Scoring Offense Rank', 'Steals Per Game Rank',
#        'Three Pt FG Defense Rank', 'Three Pt FG % Rank',
#        'Three Pt FG Per Game Rank', 'Turnover Margin Rank',
#        'Turnover Per Game Rank', 'Win-Loss Rank', 'Tournament Wins',
#        'Conference'],
#       dtype='object')

# %%
#Drop unnamed column
clean_data_df.drop('Unnamed: 0', axis=1)
# Out:
#                     Team  Assists Per. Game Rank  Assist Turnover Ratio Rank  \
# 0     A&M-Corpus Christi                      44                         141
# 1      Abilene Christian                      52                          76
# 2              Air Force                     206                         265
# 3                  Akron                     278                         177
# 4            Alabama A&M                     347                         346
# ...                  ...                     ...                         ...
# 3788          Wright St.                     233                         196
# 3789             Wyoming                     252                         127
# 3790              Xavier                     286                         238
# 3791                Yale                     152                         208
# 3792      Youngstown St.                      40                          30
#
# ...

# %%
# Scale 
# Creating a StandardScaler instance.
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

# %%
clean_data_df.head()
# Out:
#    Unnamed: 0                Team  Assists Per. Game Rank  \
# 0           0  A&M-Corpus Christi                      44
# 1           1   Abilene Christian                      52
# 2           2           Air Force                     206
# 3           3               Akron                     278
# 4           4         Alabama A&M                     347
#
#    Assist Turnover Ratio Rank  BlocksPerGame Rank  Field Goal % Rank  \
# 0                         141                 343                156
# 1                          76                 338                194
# 2                         265                 190                203
# 3                         177                 162                 70
# 4                         346                 164                349
#
#    Field Goal % Defense Rank  Fouls Per Game Rank  Free Throw % Rank  \
# 0                         90                  349                100
# ...

# %%
# One hot encoder
# Fitting the Standard Scaler with the training data.

# %%
# Import linear regression 
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt

# %%
# Set independent and dependent variables.
ast_per_game = clean_data_df['Assists Per. Game Rank']
ast_to_ratio = clean_data_df['Assist Turnover Ratio Rank']
blocks_per_game = clean_data_df['BlocksPerGame Rank']
fieldgoalprc = clean_data_df['Field Goal % Rank']
fieldgoalprcdef = clean_data_df['Field Goal % Defense Rank']
fouls_per_game = clean_data_df['Fouls Per Game Rank']
ftprc = clean_data_df['Free Throw % Rank']
reb_marg = clean_data_df['Rebound Margin Rank']
scoring_def = clean_data_df['Scoring Defense Rank']
scoring_margin = clean_data_df['Scoring Margin Rank']
scoring_off = clean_data_df['Scoring Offense Rank']
stls_per_game = clean_data_df['Steals Per Game Rank']
threept_fg_def = clean_data_df['Three Pt FG Defense Rank']
threept_fg_prc = clean_data_df['Three Pt FG % Rank']
threept_fg_per_game = clean_data_df['Three Pt FG Per Game Rank']
to_margin = clean_data_df['Turnover Margin Rank']
to_per_game = clean_data_df['Turnover Per Game Rank']
wl = clean_data_df['Win-Loss Rank']
tournament_wins = clean_data_df['Tournament Wins']

# %%
lm(qsec ~ mpg + disp + drat + wt + hp,data=mtcars) #generate multiple linear regression model

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(ast_per_game, tournament_wins)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.0x + 0.4
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, ast_to_ratio)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -38.59x + 180.17
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, blocks_per_game)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -26.69x + 177.67
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, fieldgoalprc)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -33.7x + 179.26
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, fieldgoalprcdef)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -37.2x + 179.92
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, fouls_per_game)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -14.57x + 175.42
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, ftprc)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -15.55x + 175.84
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, reb_marg)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -33.79x + 179.2
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, scoring_def)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -31.25x + 178.74
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, scoring_margin)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -46.91x + 181.69
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, scoring_off)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -31.86x + 178.86
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, stls_per_game)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -8.95x + 174.4
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, threept_fg_def)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -27.67x + 178.1
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, threept_fg_prc)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -16.1x + 158.11
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, threept_fg_per_game)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -9.53x + 174.53
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, to_margin)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -20.41x + 174.1
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, to_per_game)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -29.32x + 178.25
# The p-value is: 0.000

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(tournament_wins, wl)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -48.06x + 180.28
# The p-value is: 0.000

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(Wins * slope + intercept) for Wins in tournament_wins]

# %%
# Create a scatter plot of the x and y values.
plt.scatter(ast_per_game, tournament_wins)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(tournament_wins,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (5,20), fontsize=15, color="red")
plt.xlabel('Assists Per Game Rank')
plt.ylabel('Tournament Wins')
plt.show()

# %%
#Normalize data?

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
